# %% [markdown]
# <a href="https://colab.research.google.com/github/laranicole0/Engenharia-de-Prompt-e-Aplica-es-em-IA/blob/main/aula_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Crie uma calculadora simples**

# %%
#Calculadora Simples em payton

def calculadora():
  print("selecione a operação:")
  print("1: adição")
  print("2: subtração")
  print("3: multiplicação")
  print("4: divisão")

  #Solicita a entrada do usuário
  escolha = input("Digite sua escolha (1/2/3/4):")

  #Solicita os números
  num1 = float(input("Digite o primeiro número:"))
  num2 = float(input("Digite o segundo número:"))

  #Realiza a operação baseado na escolha
  if escolha == '1':
    print(f"Resultado: {num1 + num2}")
  elif escolha == '2':
    print(f"Resultado: {num1 - num2}")
  elif escolha == '3':
    print(f"Resultado: {num1 * num2}")
  elif escolha == '4':
    if num2 != 0:
      print(f"Resultado: {num1 / num2}")
    else:
      print("Erro: divisão por zero")
  else:
    print("Escolha inválida")

#execulta a calculadora
calculadora()
# Out:
# selecione a operação:
# 1: adição
# 2: subtração
# 3: multiplicação
# 4: divisão
# Digite sua escolha (1/2/3/4):1
# Digite o primeiro número:1.5
# Digite o segundo número:3.5
# Resultado: 5.0
